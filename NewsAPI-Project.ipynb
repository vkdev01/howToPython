# %% [markdown]
# **API Key** - f31a4798ed8147d08230cae495064e2d
#
# **Client library** - $ pip install newsapi-python

# %% [markdown]
# # using endpoints
#
# 1. I want to show my users live top and breaking news headlines
#
#     - python :-
#
#         ```python
#         import requests
#         url = ('http://newsapi.org/v2/top-headlines?'
#                'country=us&'
#                'apiKey=f31a4798ed8147d08230cae495064e2d')
#         response = requests.get(url)
#         print response.json()
#         ```
#
#     - CURL :-
#         ```bash
#         curl http://newsapi.org/v2/top-headlines -G \
#             -d country=us \
#             -d apiKey=f31a4798ed8147d08230cae495064e2d
#         ```

# %% [markdown]
# 2. you want headlines just from a specific source
#
#     - python :-
#
#         ```python
#         import requests
#         url = ('http://newsapi.org/v2/top-headlines?'
#                'sources=bbc-news&'
#                'apiKey=f31a4798ed8147d08230cae495064e2d')
#         response = requests.get(url)
#         print response.json()
#         ```
#
#     - curl :-
#
#         ```bash
#         curl http://newsapi.org/v2/top-headlines -G \
#             -d sources=bbc-news \
#             -d apiKey=f31a4798ed8147d08230cae495064e2d
#         ```

# %% [markdown]
# 3. search for news articles that mention a specific topic or keyword
#
#     - curl:
#
#         ```bash
#         curl http://newsapi.org/v2/everything -G \
#             -d q=Apple \
#             -d from=2021-01-04 \
#             -d sortBy=popularity \
#             -d apiKey=f31a4798ed8147d08230cae495064e2d
#         ```
#
#      - python:
#
#          ```python
#             import requests
#
#             url = ('http://newsapi.org/v2/everything?'
#                    'q=Apple&'
#                    'from=2021-01-04&'
#                    'sortBy=popularity&'
#                    'apiKey=f31a4798ed8147d08230cae495064e2d')
#
#             response = requests.get(url)
#
#             print r.json
#          ```

# %% [markdown]
# # endpoint examples
#
# - https://newsapi.org/v2/top-headlines?country=us&apiKey=f31a4798ed8147d08230cae495064e2d
# -
# https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/top-headlines?country=de&category=business&apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/top-headlines?q=trump&apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/top-headlines
# - https://newsapi.org/v2/everything?q=bitcoin&apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/everything?q=apple&from=2021-01-03&to=2021-01-03&sortBy=popularity&apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/everything?domains=techcrunch.com,thenextweb.com&apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/everything
# - https://newsapi.org/v2/sources?apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/sources?language=en&apiKey=f31a4798ed8147d08230cae495064e2d
# - https://newsapi.org/v2/sources?language=en&country=us&apiKey=f31a4798ed8147d08230cae495064e2d

# %%
response_json = {
    'status': 'Ok',
    'totalResults': 38,
    'articles':[
        {
            'source': {
                'id': "",
                'name': ""
            },
            'author': "",
            'title': "",
            'description': "",
            'url': "",
            'urlToImage': "",
            'publishedAt': "",
            'content' : ""
        },
        {},
        {}
    ]
}

# %%
import requests
url = ('http://newsapi.org/v2/top-headlines?'
       'country=in&'
       'apiKey=f31a4798ed8147d08230cae495064e2d')
response = requests.get(url)

# %%
type(response.json())
# Out:
# dict

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 38,
#  'articles': [{'source': {'id': None, 'name': 'Republic World'},
#    'author': 'Saurabh Sabat',
#    'title': 'SpaceX Starlink Launch Schedule: Details about Falcon 9 rocket, live stream and more - Republic World',
#    'description': 'Starlink is a satellite internet constellation which is being constructed by SpaceX providing satellite Internet access. Read on to know more.',
#    'url': 'https://www.republicworld.com/technology-news/science/spacex-starlink-launch-schedule-details-about-falcon-9-rocket-live-stream-and-more.html',
#    'urlToImage': 'https://img.republicworld.com/republic-prod/stories/promolarge/xxhdpi/huzx6zikj2gf6tgq_1610974216.jpeg?tr=f-jpeg',
#    'publishedAt': '2021-01-18T14:33:00Z',
#    'content': 'Space Exploration Technologies Corp. is an American aerospace manufacturer and space transportation services company headquartered in Hawthorne, California. It was founded in 2002 by Elon Musk with t… [+4299 chars]'},
# ...
